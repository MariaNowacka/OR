# %% [markdown]
# # Operations Research Group Project
#
# ## Scope
#
# **Primal Problem (recap)**:
#
# $$\min_{x} \quad Z = \sum_{i \in I} c_i x_i$$
#
# **Dual Problem**:
#
# $$\max_{y} \quad W = \mathbf{b}_{ub}^\top \mathbf{y} + \mathbf{x}_{ub}^\top \boldsymbol{\lambda}_{ub}$$
#
# **Dual Variables**:
#
# $y_k$ — shadow price of constraint $k$ in $A_{ub}\,\mathbf{x} \leq \mathbf{b}_{ub}$
#
# $\lambda_{ub,i}$ — shadow price of the portion cap $x_i \leq x_{ub}$
#
# **Shadow Price Interpretation**:
#
# For a binding lower-bound constraint (nutrient minimum $\geq b_j^{LB}$, encoded as $-A_j x \leq -b_j^{LB}$):
#
# $$\text{shadow\_price}_j = -y_k > 0$$
#
# A shadow price of $s$ means: if the nutrient minimum $b_j^{LB}$ increases by 1 unit, the minimum lunch cost $Z^*$ increases by $s$ USD.
#
# For a binding group cap constraint ($\sum_{i \in I_g} x_i \leq U_g$):
#
# $$\text{shadow\_price}_g = -y_k > 0$$
#
# A shadow price of $s$ means: relaxing the group cap $U_g$ by 1 gram reduces the minimum lunch cost $Z^*$ by $s$ USD.
#
# **Strong Duality Property**:
#
# $$Z^* = W^* \quad \text{(at optimality)}$$
#
# **Complementary Slackness**:
#
# $$y_k > 0 \implies \text{constraint } k \text{ is binding (slack} = 0)$$
#
# $$\text{slack}_k > 0 \implies y_k = 0$$
#
# **Constraint Index Sets**:
#
# $i \in I = \{1, 2, \ldots, 204\}$ — food items
#
# $j \in J = \{1, 2, \ldots, 29\}$ — nutrients
#
# $g \in G$ — food groups for meal realism constraints
#
# $k \in K = \{1, 2, \ldots, 34\}$ — LP constraint rows (28 nutrient constraints from $J_{\min}$, $J_{\max}$, $J_{\text{range}}$ + 6 group cap constraints from $G$)

# %%
# Necessary imports
import numpy as np
import pandas as pd

from scipy.optimize import linprog, OptimizeResult
from tabulate import tabulate

import os
import warnings
warnings.filterwarnings("ignore")

# %%
# Data loc
PATH_PRICES    = "/Users/julianyoo/Downloads/Study/PWR/Term 1/Operations Research/Project/data/food_prices_200.xlsx"
PATH_NUTRITION = "/Users/julianyoo/Downloads/Study/PWR/Term 1/Operations Research/Project/data/food_nutrition_200.xlsx"
PATH_REQ_LB    = "/Users/julianyoo/Downloads/Study/PWR/Term 1/Operations Research/Project/data/dri_lunch_lb.csv"
PATH_REQ_UB    = "/Users/julianyoo/Downloads/Study/PWR/Term 1/Operations Research/Project/data/dri_lunch_ub.csv"

# Portion cap
MAX_GRAMS_PER_FOOD = 200.0

# %%
# Data load
def load_data() -> tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    """
    Loading all required data

    Tap water should be excluded

    Returns:
    nutrition   : (204, 35) - food nutritional content per 100g
    prices      : (204, 13) - food prices per gram
    lb          : (5, 29+4) - lower bounds per age-sex group
    ub          : (5, 29+4) - upper bounds per age-sex group
    """
    nutrition = pd.read_excel(PATH_NUTRITION, keep_default_na=False)
    prices    = pd.read_excel(PATH_PRICES,    keep_default_na=False)
    lb        = pd.read_csv(PATH_REQ_LB).set_index("age_sex_group")
    ub        = pd.read_csv(PATH_REQ_UB).set_index("age_sex_group")

    # Remove water
    nutrition = nutrition[nutrition["food_name"] != "Water, Tap"].reset_index(drop=True)
    prices    = prices[prices["food_name"] != "Water, Tap"].reset_index(drop=True)

    return nutrition, prices, lb, ub

# %%
nutrition, prices, lb, ub = load_data()
print(f"Foods: {len(nutrition)}")
print(f"Groups: {list(lb.index)}")
# Out:
# Foods: 204
# Groups: ['children_4_8_MF', 'males_9_13', 'females_9_13', 'males_14_18', 'females_14_18']

# %%
# Build LP coefficient matrices
def build_matrices(
        nutrition: pd.DataFrame,
        prices:    pd.DataFrame
) -> tuple[np.ndarray, np.ndarray, list[str], list[str]]:
    """
    Constructing the obj vec c and const coeff matrix A

    Notation:
    n   : number of foods
    m   : number of nutrients
    c   : cost per gram (USD/g)
    A   : nutrient per gram

    Returns:
    c           : (n,) - obj coeff (USD per gram)
    A           : (n, m) - nutrient per gram matrix
    food_names  : list[str]
    nut_cols    : list[str]
    """
    nut_cols = list(nutrition.columns[6:])  # 29 nutrients

    merged = nutrition.merge(
        prices[["food_id", "price_per_1g_usd"]],
        on="food_id",
        how="inner"
    )

    food_names = list(merged["food_name"])
    c          = merged["price_per_1g_usd"].to_numpy(dtype=float)
    A          = merged[nut_cols].to_numpy(dtype=float) / 100.0

    return c, A, food_names, nut_cols

# %%
c, A, food_names, nut_cols = build_matrices(nutrition, prices)
print(f"Obj vector c : {c.shape}     (USD/g)")
print(f"Const mat A  : {A.shape}     (nutrient/g)")
print(f"Cost range   : ${c.min():.4f} - ${c.max():.4f} per gram")
# Out:
# Obj vector c : (204,)     (USD/g)
# Const mat A  : (204, 29)     (nutrient/g)
# Cost range   : $0.0001 - $0.0500 per gram

# %%
# Build constraints
def get_constraints() -> dict[str, list[str]]:
    """
    Classifying each nutrient into LP constraint types

    Categories:
    min_only    : sum_i a_ij x_i >= LB_j   (RDA/AI minimum requirements)
    max_only    : sum_i a_ij x_i <= UB_j   (NSLP/DGA ceilings)
    range       : LB_j <= sum_i a_ij x_i <= UB_j  (energy + fat)
    skip        : no numeric DRI -- excluded from LP constraints
    """
    min_only = [
        "protein_g",
        "carbohydrates_g",
        "dietary_fiber_g",
        "calcium_mg",
        "iron_mg",
        "magnesium_mg",
        "phosphorus_mg",
        "potassium_mg",
        "zinc_mg",
        "vitamin_a_ug_rae",
        "vitamin_d_ug",
        "vitamin_e_mg_ate",
        "vitamin_k_ug",
        "vitamin_c_mg",
        "thiamin_b1_mg",
        "riboflavin_b2_mg",
        "niacin_b3_mg",
        "vitamin_b6_mg",
        "folate_ug_dfe",
        "vitamin_b12_ug",
        "selenium_ug",
    ]
    max_only = [
        "sugars_g",
        "saturated_fat_g",
        "sodium_mg",
    ]
    range_nuts = [
        "energy_kcal",
        "total_fat_g",
    ]
    skip = [
        "monounsaturated_fat_g",
        "polyunsaturated_fat_g",
        "cholesterol_mg",
    ]

    return {
        "min_only" : min_only,
        "max_only" : max_only,
        "range"    : range_nuts,
        "skip"     : skip,
    }

# %%
constraint_sets = get_constraints()
for ctype, nuts in constraint_sets.items():
    print(f"{ctype}: {len(nuts):2d} nutrients")
# Out:
# min_only: 21 nutrients
# max_only:  3 nutrients
# range:  2 nutrients
# skip:  3 nutrients

# %%
# Food group cap
def get_group_caps(food_names: list[str]) -> dict[str, tuple[list[int], float]]:
    """
    Define food group caps for meal realism.

    For each group: a list of food indices and a combined gram cap.
    The LP must spread across food groups — no single category can dominate.

    Groups and caps:
    fluid_milk      — one standard school carton (all milk types combined)
    cooking_oils    — incidental cooking use only
    grain_products  — one grain serving (all grains/cereals combined)
    leafy_veg       — one side salad portion
    protein_foods   — one protein serving
    fruits          — one fruit serving

    Returns:
    dict mapping group_name -> (list of food indices in group, gram cap)
    """
    group_keywords = {
        "fluid_milk"    : ["milk, 2%", "milk, whole", "milk, 1%", "milk, nonfat",
                           "milk, skim", "milk, soy", "milk, almond", "milk, chocolate",
                           "milk,"],
        "cooking_oils"  : ["vegetable oil", "olive oil", "canola oil", "coconut oil"],
        "grain_products": ["cornmeal", "corn flakes", "raisin bran", "oatmeal",
                           "granola", "rice, white", "rice, brown", "pasta",
                           "spaghetti", "macaroni", "bread,", "tortilla",
                           "bagel", "pita", "quinoa", "barley", "millet",
                           "couscous", "buckwheat", "crackers", "wild rice"],
        "leafy_veg"     : ["spinach", "kale", "romaine", "lettuce", "collard",
                           "swiss chard", "bok choy", "mixed greens"],
        "protein_foods" : ["chicken", "beef", "pork", "turkey", "tuna",
                           "salmon", "tilapia", "cod", "shrimp", "sardine",
                           "mackerel", "clam", "crab", "catfish", "liver",
                           "egg", "tofu", "edamame"],
        "fruits"        : ["banana", "apple", "orange", "grape", "strawberr",
                           "blueberr", "peach", "pear", "pineapple", "watermelon",
                           "cantaloupe", "mango", "kiwi", "cherry", "plum",
                           "grapefruit", "pomegranate", "raspberry"],
    }

    group_caps = {
        "fluid_milk"    : 150.0,
        "cooking_oils"  : 3.0,
        "grain_products": 120.0,
        "leafy_veg"     : 80.0,
        "protein_foods" : 100.0,
        "fruits"        : 120.0,
    }

    groups = {}
    food_names_lower = [f.lower() for f in food_names]

    for group, keywords in group_keywords.items():
        indices = [
            i for i, name in enumerate(food_names_lower)
            if any(kw in name for kw in keywords)
        ]
        groups[group] = (indices, group_caps[group])

    return groups

# %%
groups = get_group_caps(food_names)

for group, (indices, cap) in groups.items():
    print(f"{group} (cap: {cap} g) — {len(indices)} foods")
# Out:
# fluid_milk (cap: 150.0 g) — 7 foods
# cooking_oils (cap: 3.0 g) — 4 foods
# grain_products (cap: 120.0 g) — 27 foods
# leafy_veg (cap: 80.0 g) — 9 foods
# protein_foods (cap: 100.0 g) — 47 foods
# fruits (cap: 120.0 g) — 21 foods

# %%
# Build A_ub system
def build_system(
        A:               np.ndarray,
        nut_cols:        list[str],
        lb_row:          pd.Series,
        ub_row:          pd.Series,
        constraint_sets: dict[str, list[str]],
        groups:          dict,
) -> tuple[np.ndarray, np.ndarray, list[tuple]]:
    """
    Assembles the A_ub matrix, b_ub vector, and constraint name list
    needed for linprog and dual variable extraction.

    Constraint order in A_ub:
    1. Nutrient min_only  : -A_j @ x <= -LB_j   (21 rows)
    2. Nutrient max_only  :  A_j @ x <=  UB_j   (3 rows)
    3. Nutrient range     : -A_j / A_j @ x <= -LB_j / UB_j  (4 rows)
    4. Group caps         :  sum_i x_i <= U_g   (6 rows)
    Total K = 34 rows

    Encoding:
    min constraint  (Ax >= b)  -->  -Ax <= -b
    max constraint  (Ax <= b)  -->   Ax <=  b
    range lb        (Ax >= b)  -->  -Ax <= -b
    range ub        (Ax <= b)  -->   Ax <=  b
    group cap       (1^T x <= U) --> row of 1s <= U

    Returns:
    A_ub    : (K, n) constraint matrix
    b_ub    : (K,)   constraint RHS
    names   : list of (constraint_type, nutrient_or_group, rhs_value)
    """
    nut_idx = {nut: j for j, nut in enumerate(nut_cols)}
    n       = A.shape[0]

    A_ub_rows, b_ub_rows, names = [], [], []

    def _valid(val) -> bool:
        if val == "": return False
        try: return not np.isnan(float(val))
        except: return False

    # Nutrient lower bounds: -A_j @ x <= -LB_j
    for nut in constraint_sets["min_only"]:
        j   = nut_idx[nut]
        val = lb_row.get(nut, "")
        if not _valid(val): continue
        A_ub_rows.append(-A[:, j]); b_ub_rows.append(-float(val))
        names.append(("min_lb", nut, float(val)))

    # Nutrient upper bounds: A_j @ x <= UB_j
    for nut in constraint_sets["max_only"]:
        j   = nut_idx[nut]
        val = ub_row.get(nut, "")
        if not _valid(val): continue
        A_ub_rows.append(A[:, j]); b_ub_rows.append(float(val))
        names.append(("max_ub", nut, float(val)))

    # Range constraints: both directions
    for nut in constraint_sets["range"]:
        j     = nut_idx[nut]
        v_lb  = lb_row.get(nut, "")
        v_ub  = ub_row.get(nut, "")
        if _valid(v_lb):
            A_ub_rows.append(-A[:, j]); b_ub_rows.append(-float(v_lb))
            names.append(("range_lb", nut, float(v_lb)))
        if _valid(v_ub):
            A_ub_rows.append(A[:, j]); b_ub_rows.append(float(v_ub))
            names.append(("range_ub", nut, float(v_ub)))

    # Group cap constraints: sum of x_i for i in group G <= U_g
    for group_name, (group_indices, cap) in groups.items():
        if not group_indices:
            continue
        row = np.zeros(n)
        for i in group_indices:
            row[i] = 1.0
        A_ub_rows.append(row); b_ub_rows.append(cap)
        names.append(("group_cap", group_name, cap))

    return np.array(A_ub_rows), np.array(b_ub_rows), names

# %%
# Solve LP and capture primal + dual
def solve_dual(
        group_id:        str,
        c:               np.ndarray,
        A:               np.ndarray,
        food_names:      list[str],
        nut_cols:        list[str],
        lb_row:          pd.Series,
        ub_row:          pd.Series,
        constraint_sets: dict[str, list[str]],
        groups:          dict,
) -> dict:
    """
    Solve LP and extract both primal and dual information

    Dual variables (shadow prices) sourced from res.ineqlin.marginals
    and res.upper.marginals (scipy HiGHS)

    Strong duality:
    Z* = b_ub @ mu + x_ub * sum(lam_ub)

    Shadow price convention:
    shadow_price = -mu[k]  (positive for binding constraints)
    Interpretation: 1-unit tightening of constraint k raises Z* by shadow_price USD

    Returns:
    dict with keys: group_id, status, cost_usd, primal_x, dual_mu,
                    dual_lam_ub, A_ub, b_ub, con_names, n_foods
    """
    n = len(food_names)

    A_ub, b_ub, con_names = build_system(
        A, nut_cols, lb_row, ub_row, constraint_sets, groups
    )
    bounds = [(0.0, MAX_GRAMS_PER_FOOD)] * n

    res: OptimizeResult = linprog(
        c      = c,
        A_ub   = A_ub,
        b_ub   = b_ub,
        bounds = bounds,
        method = "highs",
    )

    if res.status != 0:
        return {"group_id": group_id, "status": res.message}

    return {
        "group_id"   : group_id,
        "status"     : "Optimal",
        "cost_usd"   : round(float(res.fun), 6),
        "primal_x"   : res.x,
        "dual_mu"    : res.ineqlin.marginals,   # shadow prices for A_ub constraints
        "dual_lam_ub": res.upper.marginals,     # shadow prices for x <= x_ub bounds
        "A_ub"       : A_ub,
        "b_ub"       : b_ub,
        "con_names"  : con_names,
        "n_foods"    : int((res.x > 0.1).sum()),
    }

# %%
# Solve for all groups
dual_results = []

for group_id in lb.index:
    result = solve_dual(
        group_id        = group_id,
        c               = c,
        A               = A,
        food_names      = food_names,
        nut_cols        = nut_cols,
        lb_row          = lb.loc[group_id],
        ub_row          = ub.loc[group_id],
        constraint_sets = constraint_sets,
        groups          = groups,
    )
    dual_results.append(result)
    print(f"{group_id:25s}  Z* = ${result['cost_usd']:.6f}")
# Out:
# children_4_8_MF            Z* = $0.738656
# males_9_13                 Z* = $0.903599
# females_9_13               Z* = $0.900184
# males_14_18                Z* = $1.036012
# females_14_18              Z* = $1.019802

# %%
# Extract shadow prices mapped to constraint names
def extract_shadow_prices(result: dict) -> pd.DataFrame:
    """
    Map raw dual variables to constraint names

    shadow_price = -mu[k]
    Positive shadow price: tightening constraint k by 1 unit raises Z* by shadow_price USD
    Zero shadow price: constraint k is non-binding (complementary slackness)

    For group_cap constraints:
    shadow_price > 0 means the cap is binding — relaxing it by 1 gram reduces Z*

    Returns:
    DataFrame with columns:
        con_type, nutrient, rhs, mu, shadow_price, slack, binding
    """
    mu        = result["dual_mu"]
    A_ub      = result["A_ub"]
    b_ub      = result["b_ub"]
    x         = result["primal_x"]
    con_names = result["con_names"]

    slack = b_ub - A_ub @ x

    rows = []
    for k, (ctype, nut, rhs) in enumerate(con_names):
        sp      = round(-mu[k], 8)
        sl      = round(slack[k], 6)
        binding = abs(sl) < 1e-4
        rows.append({
            "con_type"    : ctype,
            "nutrient"    : nut,
            "rhs"         : rhs,
            "mu"          : round(mu[k], 8),
            "shadow_price": sp,
            "slack"       : sl,
            "binding"     : binding,
        })

    return pd.DataFrame(rows)

# %%
# Extract for all groups and attach to results
for result in dual_results:
    if result["status"] != "Optimal":
        continue
    result["shadow_df"] = extract_shadow_prices(result)

# %%
# Verify strong duality: Z* = W*
def verify_strong_duality(result: dict) -> dict:
    """
    Verify strong duality property: Z* = W*

    W* = b_ub @ mu + x_ub @ lam_ub

    From the lecture:
    'If the Primal has an optimal solution, the Dual also has an optimal
    solution and their objective values are exactly equal: Z* = W*'

    Returns:
    dict with z_star, w_star, gap, verified
    """
    mu      = result["dual_mu"]
    lam_ub  = result["dual_lam_ub"]
    b_ub    = result["b_ub"]
    n       = len(result["primal_x"])

    z_star = result["cost_usd"]
    w_star = b_ub @ mu + MAX_GRAMS_PER_FOOD * np.ones(n) @ lam_ub

    return {
        "group_id" : result["group_id"],
        "z_star"   : round(z_star, 6),
        "w_star"   : round(float(w_star), 6),
        "gap"      : round(abs(z_star - float(w_star)), 8),
        "verified" : np.isclose(z_star, float(w_star), rtol=1e-4),
    }

# %%
# Print strong duality verification for all groups
duality_rows = []
for result in dual_results:
    if result["status"] != "Optimal":
        continue
    v = verify_strong_duality(result)
    duality_rows.append([
        v["group_id"],
        f"${v['z_star']:.6f}",
        f"${v['w_star']:.6f}",
        f"{v['gap']:.2e}",
        "YES" if v["verified"] else "NO",
    ])

print(tabulate(
    duality_rows,
    headers=["Group", "Z* (primal)", "W* (dual)", "Gap", "Z* = W*"],
    tablefmt="rounded_outline",
))
# Out:
# ╭─────────────────┬───────────────┬─────────────┬─────────┬───────────╮
# │ Group           │ Z* (primal)   │ W* (dual)   │     Gap │ Z* = W*   │
# ├─────────────────┼───────────────┼─────────────┼─────────┼───────────┤
# │ children_4_8_MF │ $0.738656     │ $0.738656   │ 3.2e-07 │ YES       │
# │ males_9_13      │ $0.903599     │ $0.903599   │ 1.9e-07 │ YES       │
# │ females_9_13    │ $0.900184     │ $0.900184   │ 2.6e-07 │ YES       │
# │ males_14_18     │ $1.036012     │ $1.036012   │ 5e-07   │ YES       │
# │ females_14_18   │ $1.019802     │ $1.019802   │ 2.4e-07 │ YES       │
# ╰─────────────────┴───────────────┴─────────────┴─────────┴───────────╯

# %%
# Verify complementary slackness
def verify_complementary_slackness(result: dict) -> pd.DataFrame:
    """
    Verify complementary slackness theorem:

    From the lecture:
    'At the optimal solution, if a resource is not fully utilised (slack > 0),
    its shadow price must be exactly zero.'

    Applies to both nutrient constraints and group cap constraints.
    Violations: binding but zero shadow price, or non-binding but nonzero shadow price

    Returns:
    DataFrame showing binding status, shadow price, and CS check for each constraint
    """
    df   = result["shadow_df"].copy()
    ZERO = 1e-6

    df["sp_nonzero"] = df["shadow_price"].abs() > ZERO
    df["cs_holds"]   = df["binding"] == df["sp_nonzero"]

    return df[["nutrient", "con_type", "slack", "shadow_price", "binding", "sp_nonzero", "cs_holds"]]

# %%
# Print complementary slackness for all groups
for result in dual_results:
    if result["status"] != "Optimal":
        continue

    cs_df      = verify_complementary_slackness(result)
    violations = (~cs_df["cs_holds"]).sum()
    satisfied  = cs_df["cs_holds"].sum()

    print(f"\nGROUP : {result['group_id'].upper().replace('_', ' ')}")
    print(f"    CS satisfied : {satisfied} / {len(cs_df)} constraints")
    print(f"    CS violations: {violations}")

    display_rows = []
    for _, row in cs_df.iterrows():
        display_rows.append([
            row["nutrient"],
            row["con_type"],
            f"{row['slack']:.6f}",
            f"{row['shadow_price']:.6f}",
            "YES" if row["binding"] else "no",
            "YES" if row["sp_nonzero"] else "no",
            "OK" if row["cs_holds"] else "VIOLATION",
        ])

    print(tabulate(
        display_rows,
        headers=["Nutrient / Group", "Type", "Slack", "Shadow Price", "Binding", "SP != 0", "CS"],
        tablefmt="rounded_outline",
    ))
# Out:
# GROUP : CHILDREN 4 8 MF
#     CS satisfied : 34 / 34 constraints
#     CS violations: 0
# ╭────────────────────┬───────────┬────────────┬────────────────┬───────────┬───────────┬──────╮
# │ Nutrient / Group   │ Type      │      Slack │   Shadow Price │ Binding   │ SP != 0   │ CS   │
# ├────────────────────┼───────────┼────────────┼────────────────┼───────────┼───────────┼──────┤
# │ protein_g          │ min_lb    │  31.6968   │       0        │ no        │ no        │ OK   │
# │ carbohydrates_g    │ min_lb    │  10.3711   │       0        │ no        │ no        │ OK   │
# │ dietary_fiber_g    │ min_lb    │   0        │       0.005671 │ YES       │ YES       │ OK   │
# │ calcium_mg         │ min_lb    │   0        │       0.000963 │ YES       │ YES       │ OK   │
# │ iron_mg            │ min_lb    │   1.73792  │       0        │ no        │ no        │ OK   │
# │ magnesium_mg       │ min_lb    │ 118.1      │       0        │ no        │ no        │ OK   │
# │ phosphorus_mg      │ min_lb    │ 425.059    │       0        │ no        │ no        │ OK   │
# │ potassium_mg       │ min_lb    │ 156.735    │       0        │ no        │ no        │ OK   │
# │ zinc_mg            │ min_lb    │   2.42141  │       0        │ no        │ no        │ OK   │
# │ vitamin_a_ug_rae   │ min_lb    │  -0        │       0.000105 │ YES       │ YES       │ OK   │
# │ vitamin_d_ug       │ min_lb    │   0        │       0.047198 │ YES       │ YES       │ OK   │
# │ vitamin_e_mg_ate   │ min_lb    │   0        │       0.004263 │ YES       │ YES       │ OK   │
# │ vitamin_k_ug       │ min_lb    │   1.65444  │       0        │ no        │ no        │ OK   │
# │ vitamin_c_mg       │ min_lb    │   2.23835  │       0        │ no        │ no        │ OK   │
# │ thiamin_b1_mg      │ min_lb    │   0.38176  │       0        │ no        │ no        │ OK   │
# │ riboflavin_b2_mg   │ min_lb    │   0.42083  │       0        │ no        │ no        │ OK   │
# │ niacin_b3_mg       │ min_lb    │   8.57821  │       0        │ no        │ no        │ OK   │
# │ vitamin_b6_mg      │ min_lb    │   0.613043 │       0        │ no        │ no        │ OK   │
# │ folate_ug_dfe      │ min_lb    │  -0        │       0.000762 │ YES       │ YES       │ OK   │
# │ vitamin_b12_ug     │ min_lb    │   1.40326  │       0        │ no        │ no        │ OK   │
# │ selenium_ug        │ min_lb    │  28.2255   │       0        │ no        │ no        │ OK   │
# │ sugars_g           │ max_ub    │  -0        │       0.003473 │ YES       │ YES       │ OK   │
# │ saturated_fat_g    │ max_ub    │   1.0115   │       0        │ no        │ no        │ OK   │
# │ sodium_mg          │ max_ub    │ 843.86     │       0        │ no        │ no        │ OK   │
# │ energy_kcal        │ range_lb  │   0        │       0.000634 │ YES       │ YES       │ OK   │
# │ energy_kcal        │ range_ub  │ 100        │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_lb  │   9.3233   │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_ub  │  -0        │       0.00069  │ YES       │ YES       │ OK   │
# │ fluid_milk         │ group_cap │   0        │       0.000949 │ YES       │ YES       │ OK   │
# │ cooking_oils       │ group_cap │   0        │       0.002111 │ YES       │ YES       │ OK   │
# │ grain_products     │ group_cap │  80.412    │       0        │ no        │ no        │ OK   │
# │ leafy_veg          │ group_cap │  76.1922   │       0        │ no        │ no        │ OK   │
# │ protein_foods      │ group_cap │   0        │       4.1e-05  │ YES       │ YES       │ OK   │
# │ fruits             │ group_cap │  17.2886   │       0        │ no        │ no        │ OK   │
# ╰────────────────────┴───────────┴────────────┴────────────────┴───────────┴───────────┴──────╯
#
# GROUP : MALES 9 13
#     CS satisfied : 34 / 34 constraints
#     CS violations: 0
# ╭────────────────────┬───────────┬────────────┬────────────────┬───────────┬───────────┬──────╮
# │ Nutrient / Group   │ Type      │      Slack │   Shadow Price │ Binding   │ SP != 0   │ CS   │
# ├────────────────────┼───────────┼────────────┼────────────────┼───────────┼───────────┼──────┤
# │ protein_g          │ min_lb    │  28.6616   │       0        │ no        │ no        │ OK   │
# │ carbohydrates_g    │ min_lb    │  17.8685   │       0        │ no        │ no        │ OK   │
# │ dietary_fiber_g    │ min_lb    │   0        │       0.002276 │ YES       │ YES       │ OK   │
# │ calcium_mg         │ min_lb    │   0        │       0.001369 │ YES       │ YES       │ OK   │
# │ iron_mg            │ min_lb    │   1.7252   │       0        │ no        │ no        │ OK   │
# │ magnesium_mg       │ min_lb    │ 107.567    │       0        │ no        │ no        │ OK   │
# │ phosphorus_mg      │ min_lb    │ 219.997    │       0        │ no        │ no        │ OK   │
# │ potassium_mg       │ min_lb    │ 193.72     │       0        │ no        │ no        │ OK   │
# │ zinc_mg            │ min_lb    │   1.69188  │       0        │ no        │ no        │ OK   │
# │ vitamin_a_ug_rae   │ min_lb    │  30.4316   │       0        │ no        │ no        │ OK   │
# │ vitamin_d_ug       │ min_lb    │   0        │       0.039588 │ YES       │ YES       │ OK   │
# │ vitamin_e_mg_ate   │ min_lb    │   0        │       0.003942 │ YES       │ YES       │ OK   │
# │ vitamin_k_ug       │ min_lb    │ 150.65     │       0        │ no        │ no        │ OK   │
# │ vitamin_c_mg       │ min_lb    │   9.76934  │       0        │ no        │ no        │ OK   │
# │ thiamin_b1_mg      │ min_lb    │   0.30905  │       0        │ no        │ no        │ OK   │
# │ riboflavin_b2_mg   │ min_lb    │   0.311661 │       0        │ no        │ no        │ OK   │
# │ niacin_b3_mg       │ min_lb    │   7.25373  │       0        │ no        │ no        │ OK   │
# │ vitamin_b6_mg      │ min_lb    │   0.50123  │       0        │ no        │ no        │ OK   │
# │ folate_ug_dfe      │ min_lb    │   0        │       0.000303 │ YES       │ YES       │ OK   │
# │ vitamin_b12_ug     │ min_lb    │   1.24606  │       0        │ no        │ no        │ OK   │
# │ selenium_ug        │ min_lb    │  25.3287   │       0        │ no        │ no        │ OK   │
# │ sugars_g           │ max_ub    │   1.19802  │       0        │ no        │ no        │ OK   │
# │ saturated_fat_g    │ max_ub    │   1.3534   │       0        │ no        │ no        │ OK   │
# │ sodium_mg          │ max_ub    │ 949.61     │       0        │ no        │ no        │ OK   │
# │ energy_kcal        │ range_lb  │   0        │       0.000728 │ YES       │ YES       │ OK   │
# │ energy_kcal        │ range_ub  │ 100        │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_lb  │   7.2778   │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_ub  │  -0        │       0.001327 │ YES       │ YES       │ OK   │
# │ fluid_milk         │ group_cap │   0        │       0.001497 │ YES       │ YES       │ OK   │
# │ cooking_oils       │ group_cap │   0        │       0.002255 │ YES       │ YES       │ OK   │
# │ grain_products     │ group_cap │  75.0379   │       0        │ no        │ no        │ OK   │
# │ leafy_veg          │ group_cap │  41.8305   │       0        │ no        │ no        │ OK   │
# │ protein_foods      │ group_cap │   0        │       0.000163 │ YES       │ YES       │ OK   │
# │ fruits             │ group_cap │   0        │       0.000214 │ YES       │ YES       │ OK   │
# ╰────────────────────┴───────────┴────────────┴────────────────┴───────────┴───────────┴──────╯
#
# GROUP : FEMALES 9 13
#     CS satisfied : 34 / 34 constraints
#     CS violations: 0
# ╭────────────────────┬───────────┬────────────┬────────────────┬───────────┬───────────┬──────╮
# │ Nutrient / Group   │ Type      │      Slack │   Shadow Price │ Binding   │ SP != 0   │ CS   │
# ├────────────────────┼───────────┼────────────┼────────────────┼───────────┼───────────┼──────┤
# │ protein_g          │ min_lb    │  28.2661   │       0        │ no        │ no        │ OK   │
# │ carbohydrates_g    │ min_lb    │  17.8181   │       0        │ no        │ no        │ OK   │
# │ dietary_fiber_g    │ min_lb    │  -0        │       0.002276 │ YES       │ YES       │ OK   │
# │ calcium_mg         │ min_lb    │   0        │       0.001369 │ YES       │ YES       │ OK   │
# │ iron_mg            │ min_lb    │   1.45469  │       0        │ no        │ no        │ OK   │
# │ magnesium_mg       │ min_lb    │  86.2861   │       0        │ no        │ no        │ OK   │
# │ phosphorus_mg      │ min_lb    │ 193.988    │       0        │ no        │ no        │ OK   │
# │ potassium_mg       │ min_lb    │ 219.42     │       0        │ no        │ no        │ OK   │
# │ zinc_mg            │ min_lb    │   1.5328   │       0        │ no        │ no        │ OK   │
# │ vitamin_a_ug_rae   │ min_lb    │  43.117    │       0        │ no        │ no        │ OK   │
# │ vitamin_d_ug       │ min_lb    │   0        │       0.039588 │ YES       │ YES       │ OK   │
# │ vitamin_e_mg_ate   │ min_lb    │   0        │       0.003942 │ YES       │ YES       │ OK   │
# │ vitamin_k_ug       │ min_lb    │ 166.618    │       0        │ no        │ no        │ OK   │
# │ vitamin_c_mg       │ min_lb    │  10.9897   │       0        │ no        │ no        │ OK   │
# │ thiamin_b1_mg      │ min_lb    │   0.215018 │       0        │ no        │ no        │ OK   │
# │ riboflavin_b2_mg   │ min_lb    │   0.321341 │       0        │ no        │ no        │ OK   │
# │ niacin_b3_mg       │ min_lb    │   7.15721  │       0        │ no        │ no        │ OK   │
# │ vitamin_b6_mg      │ min_lb    │   0.489761 │       0        │ no        │ no        │ OK   │
# │ folate_ug_dfe      │ min_lb    │   0        │       0.000303 │ YES       │ YES       │ OK   │
# │ vitamin_b12_ug     │ min_lb    │   1.25007  │       0        │ no        │ no        │ OK   │
# │ selenium_ug        │ min_lb    │  24.2668   │       0        │ no        │ no        │ OK   │
# │ sugars_g           │ max_ub    │   1.09025  │       0        │ no        │ no        │ OK   │
# │ saturated_fat_g    │ max_ub    │   0.920892 │       0        │ no        │ no        │ OK   │
# │ sodium_mg          │ max_ub    │ 925.856    │       0        │ no        │ no        │ OK   │
# │ energy_kcal        │ range_lb  │   0        │       0.000728 │ YES       │ YES       │ OK   │
# │ energy_kcal        │ range_ub  │ 100        │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_lb  │   9.2878   │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_ub  │  -0        │       0.001327 │ YES       │ YES       │ OK   │
# │ fluid_milk         │ group_cap │   0        │       0.001497 │ YES       │ YES       │ OK   │
# │ cooking_oils       │ group_cap │   0        │       0.002255 │ YES       │ YES       │ OK   │
# │ grain_products     │ group_cap │  73.169    │       0        │ no        │ no        │ OK   │
# │ leafy_veg          │ group_cap │  38.2823   │       0        │ no        │ no        │ OK   │
# │ protein_foods      │ group_cap │   0        │       0.000163 │ YES       │ YES       │ OK   │
# │ fruits             │ group_cap │   0        │       0.000214 │ YES       │ YES       │ OK   │
# ╰────────────────────┴───────────┴────────────┴────────────────┴───────────┴───────────┴──────╯
#
# GROUP : MALES 14 18
#     CS satisfied : 34 / 34 constraints
#     CS violations: 0
# ╭────────────────────┬───────────┬────────────┬────────────────┬───────────┬───────────┬──────╮
# │ Nutrient / Group   │ Type      │      Slack │   Shadow Price │ Binding   │ SP != 0   │ CS   │
# ├────────────────────┼───────────┼────────────┼────────────────┼───────────┼───────────┼──────┤
# │ protein_g          │ min_lb    │  26.6625   │       0        │ no        │ no        │ OK   │
# │ carbohydrates_g    │ min_lb    │  40.1862   │       0        │ no        │ no        │ OK   │
# │ dietary_fiber_g    │ min_lb    │  -0        │       0.005329 │ YES       │ YES       │ OK   │
# │ calcium_mg         │ min_lb    │   0        │       0.001043 │ YES       │ YES       │ OK   │
# │ iron_mg            │ min_lb    │   2.18414  │       0        │ no        │ no        │ OK   │
# │ magnesium_mg       │ min_lb    │  91.9514   │       0        │ no        │ no        │ OK   │
# │ phosphorus_mg      │ min_lb    │ 343.585    │       0        │ no        │ no        │ OK   │
# │ potassium_mg       │ min_lb    │ 169.137    │       0        │ no        │ no        │ OK   │
# │ zinc_mg            │ min_lb    │   1.57774  │       0        │ no        │ no        │ OK   │
# │ vitamin_a_ug_rae   │ min_lb    │   0        │       0.000117 │ YES       │ YES       │ OK   │
# │ vitamin_d_ug       │ min_lb    │   0        │       0.04557  │ YES       │ YES       │ OK   │
# │ vitamin_e_mg_ate   │ min_lb    │   0        │       0.005262 │ YES       │ YES       │ OK   │
# │ vitamin_k_ug       │ min_lb    │ 167.768    │       0        │ no        │ no        │ OK   │
# │ vitamin_c_mg       │ min_lb    │   2.5011   │       0        │ no        │ no        │ OK   │
# │ thiamin_b1_mg      │ min_lb    │   0.316201 │       0        │ no        │ no        │ OK   │
# │ riboflavin_b2_mg   │ min_lb    │   0.328321 │       0        │ no        │ no        │ OK   │
# │ niacin_b3_mg       │ min_lb    │   7.60442  │       0        │ no        │ no        │ OK   │
# │ vitamin_b6_mg      │ min_lb    │   0.576264 │       0        │ no        │ no        │ OK   │
# │ folate_ug_dfe      │ min_lb    │   0        │       0.00057  │ YES       │ YES       │ OK   │
# │ vitamin_b12_ug     │ min_lb    │   1.64064  │       0        │ no        │ no        │ OK   │
# │ selenium_ug        │ min_lb    │  27.4527   │       0        │ no        │ no        │ OK   │
# │ sugars_g           │ max_ub    │   3.6694   │       0        │ no        │ no        │ OK   │
# │ saturated_fat_g    │ max_ub    │   2.06882  │       0        │ no        │ no        │ OK   │
# │ sodium_mg          │ max_ub    │ 972.531    │       0        │ no        │ no        │ OK   │
# │ energy_kcal        │ range_lb  │  -0        │       0.000644 │ YES       │ YES       │ OK   │
# │ energy_kcal        │ range_ub  │ 100        │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_lb  │   5.1011   │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_ub  │   0        │       0.000834 │ YES       │ YES       │ OK   │
# │ fluid_milk         │ group_cap │   0        │       0.001193 │ YES       │ YES       │ OK   │
# │ cooking_oils       │ group_cap │   0        │       0.002233 │ YES       │ YES       │ OK   │
# │ grain_products     │ group_cap │  48.0326   │       0        │ no        │ no        │ OK   │
# │ leafy_veg          │ group_cap │  37.1382   │       0        │ no        │ no        │ OK   │
# │ protein_foods      │ group_cap │   0        │       5.6e-05  │ YES       │ YES       │ OK   │
# │ fruits             │ group_cap │   0        │       0.000221 │ YES       │ YES       │ OK   │
# ╰────────────────────┴───────────┴────────────┴────────────────┴───────────┴───────────┴──────╯
#
# GROUP : FEMALES 14 18
#     CS satisfied : 34 / 34 constraints
#     CS violations: 0
# ╭────────────────────┬───────────┬────────────┬────────────────┬───────────┬───────────┬──────╮
# │ Nutrient / Group   │ Type      │      Slack │   Shadow Price │ Binding   │ SP != 0   │ CS   │
# ├────────────────────┼───────────┼────────────┼────────────────┼───────────┼───────────┼──────┤
# │ protein_g          │ min_lb    │  26.6671   │       0        │ no        │ no        │ OK   │
# │ carbohydrates_g    │ min_lb    │  40.9539   │       0        │ no        │ no        │ OK   │
# │ dietary_fiber_g    │ min_lb    │   0.692936 │       0        │ no        │ no        │ OK   │
# │ calcium_mg         │ min_lb    │   0        │       0.001179 │ YES       │ YES       │ OK   │
# │ iron_mg            │ min_lb    │   0.154526 │       0        │ no        │ no        │ OK   │
# │ magnesium_mg       │ min_lb    │  63.3631   │       0        │ no        │ no        │ OK   │
# │ phosphorus_mg      │ min_lb    │ 247.539    │       0        │ no        │ no        │ OK   │
# │ potassium_mg       │ min_lb    │ 303.372    │       0        │ no        │ no        │ OK   │
# │ zinc_mg            │ min_lb    │   1.6504   │       0        │ no        │ no        │ OK   │
# │ vitamin_a_ug_rae   │ min_lb    │  53.8772   │       0        │ no        │ no        │ OK   │
# │ vitamin_d_ug       │ min_lb    │   0        │       0.043194 │ YES       │ YES       │ OK   │
# │ vitamin_e_mg_ate   │ min_lb    │   0        │       0.004999 │ YES       │ YES       │ OK   │
# │ vitamin_k_ug       │ min_lb    │ 238.643    │       0        │ no        │ no        │ OK   │
# │ vitamin_c_mg       │ min_lb    │  10.9976   │       0        │ no        │ no        │ OK   │
# │ thiamin_b1_mg      │ min_lb    │   0.175005 │       0        │ no        │ no        │ OK   │
# │ riboflavin_b2_mg   │ min_lb    │   0.377347 │       0        │ no        │ no        │ OK   │
# │ niacin_b3_mg       │ min_lb    │   7.77096  │       0        │ no        │ no        │ OK   │
# │ vitamin_b6_mg      │ min_lb    │   0.55779  │       0        │ no        │ no        │ OK   │
# │ folate_ug_dfe      │ min_lb    │   0        │       0.000686 │ YES       │ YES       │ OK   │
# │ vitamin_b12_ug     │ min_lb    │   1.01867  │       0        │ no        │ no        │ OK   │
# │ selenium_ug        │ min_lb    │  23.0902   │       0        │ no        │ no        │ OK   │
# │ sugars_g           │ max_ub    │   3.96937  │       0        │ no        │ no        │ OK   │
# │ saturated_fat_g    │ max_ub    │   1.62007  │       0        │ no        │ no        │ OK   │
# │ sodium_mg          │ max_ub    │ 925.919    │       0        │ no        │ no        │ OK   │
# │ energy_kcal        │ range_lb  │   0        │       0.000754 │ YES       │ YES       │ OK   │
# │ energy_kcal        │ range_ub  │ 100        │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_lb  │  11.1011   │       0        │ no        │ no        │ OK   │
# │ total_fat_g        │ range_ub  │   0        │       0.00171  │ YES       │ YES       │ OK   │
# │ fluid_milk         │ group_cap │   0        │       0.001343 │ YES       │ YES       │ OK   │
# │ cooking_oils       │ group_cap │   0        │       0.00228  │ YES       │ YES       │ OK   │
# │ grain_products     │ group_cap │  42.582    │       0        │ no        │ no        │ OK   │
# │ leafy_veg          │ group_cap │  21.2506   │       0        │ no        │ no        │ OK   │
# │ protein_foods      │ group_cap │   0        │       0.000175 │ YES       │ YES       │ OK   │
# │ fruits             │ group_cap │   0        │       0.000211 │ YES       │ YES       │ OK   │
# ╰────────────────────┴───────────┴────────────┴────────────────┴───────────┴───────────┴──────╯

# %%
# Print dual results summary per group
def print_dual_results(result: dict) -> None:
    """
    Print shadow prices and duality summary for one group

    Sections:
    1. Strong duality verification (Z* = W*)
    2. Active shadow prices — nutrient constraints (binding, ranked by cost impact)
    3. Active shadow prices — group cap constraints (binding caps and their cost impact)
    """
    if result["status"] != "Optimal":
        return

    gid = result["group_id"]
    print(f"\nGROUP : {gid.upper().replace('_', ' ')}")
    print(f"    Z* = ${result['cost_usd']:.6f}")

    # Strong duality
    v = verify_strong_duality(result)
    print(f"    W* = ${v['w_star']:.6f}    Z* = W* : {'YES' if v['verified'] else 'NO'}")

    df     = result["shadow_df"]
    active = df[df["shadow_price"].abs() > 1e-6].sort_values(
        "shadow_price", ascending=False
    )

    # Nutrient constraints
    nut_active = active[active["con_type"] != "group_cap"]
    if not nut_active.empty:
        print(f"\n    Nutrient shadow prices (binding constraints only)")
        print(f"    Interpretation: +1 unit tightening raises Z* by shadow_price USD")
        rows = []
        for _, row in nut_active.iterrows():
            rows.append([
                row["nutrient"],
                row["con_type"],
                f"{row['rhs']:.3f}",
                f"${row['shadow_price']:.6f}",
            ])
        print(tabulate(
            rows,
            headers=["Nutrient", "Type", "RHS", "Shadow price (USD/unit)"],
            tablefmt="rounded_outline",
        ))

    # Group cap constraints
    grp_active = active[active["con_type"] == "group_cap"]
    if not grp_active.empty:
        print(f"\n    Group cap shadow prices (binding caps only)")
        print(f"    Interpretation: relaxing cap by +1 gram reduces Z* by shadow_price USD")
        rows = []
        for _, row in grp_active.iterrows():
            rows.append([
                row["nutrient"],
                f"{row['rhs']:.1f} g",
                f"${row['shadow_price']:.6f}",
            ])
        print(tabulate(
            rows,
            headers=["Group", "Cap (g)", "Shadow price (USD/g)"],
            tablefmt="rounded_outline",
        ))

# %%
for result in dual_results:
    print_dual_results(result)
# Out:
# GROUP : CHILDREN 4 8 MF
#     Z* = $0.738656
#     W* = $0.738656    Z* = W* : YES
#
#     Nutrient shadow prices (binding constraints only)
#     Interpretation: +1 unit tightening raises Z* by shadow_price USD
# ╭──────────────────┬──────────┬─────────┬───────────────────────────╮
# │ Nutrient         │ Type     │     RHS │ Shadow price (USD/unit)   │
# ├──────────────────┼──────────┼─────────┼───────────────────────────┤
# │ vitamin_d_ug     │ min_lb   │   4.5   │ $0.047198                 │
# │ dietary_fiber_g  │ min_lb   │   7.5   │ $0.005671                 │
# │ vitamin_e_mg_ate │ min_lb   │   2.1   │ $0.004263                 │
# │ sugars_g         │ max_ub   │  15     │ $0.003473                 │
# │ calcium_mg       │ min_lb   │ 300     │ $0.000963                 │
# │ folate_ug_dfe    │ min_lb   │  60     │ $0.000762                 │
# │ total_fat_g      │ range_ub │  23.333 │ $0.000690                 │
# │ energy_kcal      │ range_lb │ 550     │ $0.000634                 │
# │ vitamin_a_ug_rae │ min_lb   │ 120     │ $0.000105                 │
# ╰──────────────────┴──────────┴─────────┴───────────────────────────╯
#
#     Group cap shadow prices (binding caps only)
#     Interpretation: relaxing cap by +1 gram reduces Z* by shadow_price USD
# ╭───────────────┬───────────┬────────────────────────╮
# │ Group         │ Cap (g)   │ Shadow price (USD/g)   │
# ├───────────────┼───────────┼────────────────────────┤
# │ cooking_oils  │ 3.0 g     │ $0.002111              │
# │ fluid_milk    │ 150.0 g   │ $0.000949              │
# │ protein_foods │ 100.0 g   │ $0.000041              │
# ╰───────────────┴───────────┴────────────────────────╯
#
# GROUP : MALES 9 13
#     Z* = $0.903599
#     W* = $0.903599    Z* = W* : YES
#
#     Nutrient shadow prices (binding constraints only)
#     Interpretation: +1 unit tightening raises Z* by shadow_price USD
# ╭──────────────────┬──────────┬─────────┬───────────────────────────╮
# │ Nutrient         │ Type     │     RHS │ Shadow price (USD/unit)   │
# ├──────────────────┼──────────┼─────────┼───────────────────────────┤
# │ vitamin_d_ug     │ min_lb   │   4.5   │ $0.039588                 │
# │ vitamin_e_mg_ate │ min_lb   │   3.3   │ $0.003942                 │
# │ dietary_fiber_g  │ min_lb   │   9.3   │ $0.002276                 │
# │ calcium_mg       │ min_lb   │ 390     │ $0.001369                 │
# │ total_fat_g      │ range_ub │  25.278 │ $0.001327                 │
# │ energy_kcal      │ range_lb │ 600     │ $0.000728                 │
# │ folate_ug_dfe    │ min_lb   │  90     │ $0.000303                 │
# ╰──────────────────┴──────────┴─────────┴───────────────────────────╯
#
#     Group cap shadow prices (binding caps only)
#     Interpretation: relaxing cap by +1 gram reduces Z* by shadow_price USD
# ╭───────────────┬───────────┬────────────────────────╮
# │ Group         │ Cap (g)   │ Shadow price (USD/g)   │
# ├───────────────┼───────────┼────────────────────────┤
# │ cooking_oils  │ 3.0 g     │ $0.002255              │
# │ fluid_milk    │ 150.0 g   │ $0.001497              │
# │ fruits        │ 120.0 g   │ $0.000214              │
# │ protein_foods │ 100.0 g   │ $0.000163              │
# ╰───────────────┴───────────┴────────────────────────╯
#
# GROUP : FEMALES 9 13
#     Z* = $0.900184
#     W* = $0.900184    Z* = W* : YES
#
#     Nutrient shadow prices (binding constraints only)
#     Interpretation: +1 unit tightening raises Z* by shadow_price USD
# ╭──────────────────┬──────────┬─────────┬───────────────────────────╮
# │ Nutrient         │ Type     │     RHS │ Shadow price (USD/unit)   │
# ├──────────────────┼──────────┼─────────┼───────────────────────────┤
# │ vitamin_d_ug     │ min_lb   │   4.5   │ $0.039588                 │
# │ vitamin_e_mg_ate │ min_lb   │   3.3   │ $0.003942                 │
# │ dietary_fiber_g  │ min_lb   │   7.8   │ $0.002276                 │
# │ calcium_mg       │ min_lb   │ 390     │ $0.001369                 │
# │ total_fat_g      │ range_ub │  25.278 │ $0.001327                 │
# │ energy_kcal      │ range_lb │ 600     │ $0.000728                 │
# │ folate_ug_dfe    │ min_lb   │  90     │ $0.000303                 │
# ╰──────────────────┴──────────┴─────────┴───────────────────────────╯
#
#     Group cap shadow prices (binding caps only)
#     Interpretation: relaxing cap by +1 gram reduces Z* by shadow_price USD
# ╭───────────────┬───────────┬────────────────────────╮
# │ Group         │ Cap (g)   │ Shadow price (USD/g)   │
# ├───────────────┼───────────┼────────────────────────┤
# │ cooking_oils  │ 3.0 g     │ $0.002255              │
# │ fluid_milk    │ 150.0 g   │ $0.001497              │
# │ fruits        │ 120.0 g   │ $0.000214              │
# │ protein_foods │ 100.0 g   │ $0.000163              │
# ╰───────────────┴───────────┴────────────────────────╯
#
# GROUP : MALES 14 18
#     Z* = $1.036012
#     W* = $1.036012    Z* = W* : YES
#
#     Nutrient shadow prices (binding constraints only)
#     Interpretation: +1 unit tightening raises Z* by shadow_price USD
# ╭──────────────────┬──────────┬─────────┬───────────────────────────╮
# │ Nutrient         │ Type     │     RHS │ Shadow price (USD/unit)   │
# ├──────────────────┼──────────┼─────────┼───────────────────────────┤
# │ vitamin_d_ug     │ min_lb   │   4.5   │ $0.045570                 │
# │ dietary_fiber_g  │ min_lb   │  11.4   │ $0.005329                 │
# │ vitamin_e_mg_ate │ min_lb   │   4.5   │ $0.005262                 │
# │ calcium_mg       │ min_lb   │ 390     │ $0.001043                 │
# │ total_fat_g      │ range_ub │  31.111 │ $0.000834                 │
# │ energy_kcal      │ range_lb │ 750     │ $0.000644                 │
# │ folate_ug_dfe    │ min_lb   │ 120     │ $0.000570                 │
# │ vitamin_a_ug_rae │ min_lb   │ 270     │ $0.000117                 │
# ╰──────────────────┴──────────┴─────────┴───────────────────────────╯
#
#     Group cap shadow prices (binding caps only)
#     Interpretation: relaxing cap by +1 gram reduces Z* by shadow_price USD
# ╭───────────────┬───────────┬────────────────────────╮
# │ Group         │ Cap (g)   │ Shadow price (USD/g)   │
# ├───────────────┼───────────┼────────────────────────┤
# │ cooking_oils  │ 3.0 g     │ $0.002233              │
# │ fluid_milk    │ 150.0 g   │ $0.001193              │
# │ fruits        │ 120.0 g   │ $0.000221              │
# │ protein_foods │ 100.0 g   │ $0.000056              │
# ╰───────────────┴───────────┴────────────────────────╯
#
# GROUP : FEMALES 14 18
#     Z* = $1.019802
#     W* = $1.019802    Z* = W* : YES
#
#     Nutrient shadow prices (binding constraints only)
#     Interpretation: +1 unit tightening raises Z* by shadow_price USD
# ╭──────────────────┬──────────┬─────────┬───────────────────────────╮
# │ Nutrient         │ Type     │     RHS │ Shadow price (USD/unit)   │
# ├──────────────────┼──────────┼─────────┼───────────────────────────┤
# │ vitamin_d_ug     │ min_lb   │   4.5   │ $0.043194                 │
# │ vitamin_e_mg_ate │ min_lb   │   4.5   │ $0.004999                 │
# │ total_fat_g      │ range_ub │  31.111 │ $0.001710                 │
# │ calcium_mg       │ min_lb   │ 390     │ $0.001179                 │
# │ energy_kcal      │ range_lb │ 750     │ $0.000754                 │
# │ folate_ug_dfe    │ min_lb   │ 120     │ $0.000686                 │
# ╰──────────────────┴──────────┴─────────┴───────────────────────────╯
#
#     Group cap shadow prices (binding caps only)
#     Interpretation: relaxing cap by +1 gram reduces Z* by shadow_price USD
# ╭───────────────┬───────────┬────────────────────────╮
# │ Group         │ Cap (g)   │ Shadow price (USD/g)   │
# ├───────────────┼───────────┼────────────────────────┤
# │ cooking_oils  │ 3.0 g     │ $0.002280              │
# │ fluid_milk    │ 150.0 g   │ $0.001343              │
# │ fruits        │ 120.0 g   │ $0.000211              │
# │ protein_foods │ 100.0 g   │ $0.000175              │
# ╰───────────────┴───────────┴────────────────────────╯

# %%
# Cross-group shadow price comparison
def print_shadow_comparison(dual_results: list[dict]) -> None:
    """
    Compare shadow prices across all groups for binding constraints

    Nutrient constraints and group cap constraints shown separately
    """
    all_rows = []
    for result in dual_results:
        if result["status"] != "Optimal":
            continue
        df     = result["shadow_df"]
        active = df[df["shadow_price"].abs() > 1e-6][["nutrient", "con_type", "shadow_price"]].copy()
        active["group"] = result["group_id"]
        all_rows.append(active)

    combined = pd.concat(all_rows, ignore_index=True)

    # Nutrient constraints
    nut_combined = combined[combined["con_type"] != "group_cap"]
    if not nut_combined.empty:
        pivot = (
            nut_combined
            .pivot_table(index="nutrient", columns="group", values="shadow_price", fill_value=0.0)
            .reset_index()
        )
        print("Nutrient shadow prices across groups (USD per unit tightening)")
        print(tabulate(
            pivot,
            headers="keys",
            tablefmt="rounded_outline",
            floatfmt=".6f",
            showindex=False,
        ))

    # Group cap constraints
    grp_combined = combined[combined["con_type"] == "group_cap"]
    if not grp_combined.empty:
        pivot_grp = (
            grp_combined
            .pivot_table(index="nutrient", columns="group", values="shadow_price", fill_value=0.0)
            .reset_index()
        )
        print("\nGroup cap shadow prices across groups (USD per gram cap relaxation)")
        print(tabulate(
            pivot_grp,
            headers="keys",
            tablefmt="rounded_outline",
            floatfmt=".6f",
            showindex=False,
        ))

# %%
print_shadow_comparison(dual_results)
# Out:
# Nutrient shadow prices across groups (USD per unit tightening)
# ╭──────────────────┬───────────────────┬─────────────────┬────────────────┬───────────────┬──────────────╮
# │ nutrient         │   children_4_8_MF │   females_14_18 │   females_9_13 │   males_14_18 │   males_9_13 │
# ├──────────────────┼───────────────────┼─────────────────┼────────────────┼───────────────┼──────────────┤
# │ calcium_mg       │          0.000963 │        0.001179 │       0.001369 │      0.001043 │     0.001369 │
# │ dietary_fiber_g  │          0.005671 │        0.000000 │       0.002276 │      0.005329 │     0.002276 │
# │ energy_kcal      │          0.000634 │        0.000754 │       0.000728 │      0.000644 │     0.000728 │
# │ folate_ug_dfe    │          0.000762 │        0.000686 │       0.000303 │      0.000570 │     0.000303 │
# │ sugars_g         │          0.003473 │        0.000000 │       0.000000 │      0.000000 │     0.000000 │
# │ total_fat_g      │          0.000690 │        0.001710 │       0.001327 │      0.000834 │     0.001327 │
# │ vitamin_a_ug_rae │          0.000105 │        0.000000 │       0.000000 │      0.000117 │     0.000000 │
# │ vitamin_d_ug     │          0.047198 │        0.043194 │       0.039588 │      0.045570 │     0.039588 │
# │ vitamin_e_mg_ate │          0.004263 │        0.004999 │       0.003942 │      0.005262 │     0.003942 │
# ╰──────────────────┴───────────────────┴─────────────────┴────────────────┴───────────────┴──────────────╯
#
# Group cap shadow prices across groups (USD per gram cap relaxation)
# ╭───────────────┬───────────────────┬─────────────────┬────────────────┬───────────────┬──────────────╮
# │ nutrient      │   children_4_8_MF │   females_14_18 │   females_9_13 │   males_14_18 │   males_9_13 │
# ├───────────────┼───────────────────┼─────────────────┼────────────────┼───────────────┼──────────────┤
# │ cooking_oils  │          0.002111 │        0.002280 │       0.002255 │      0.002233 │     0.002255 │
# │ fluid_milk    │          0.000949 │        0.001343 │       0.001497 │      0.001193 │     0.001497 │
# │ fruits        │          0.000000 │        0.000211 │       0.000214 │      0.000221 │     0.000214 │
# │ protein_foods │          0.000041 │        0.000175 │       0.000163 │      0.000056 │     0.000163 │
# ╰───────────────┴───────────────────┴─────────────────┴────────────────┴───────────────┴──────────────╯

# %%
# Save dual results to markdown
def save_dual_md(result: dict, save_path: str = ".") -> None:
    """
    Save duality analysis for one group as a Markdown file

    Output: dual_{group_id}.md
    Sections: header, nutrient shadow prices, group cap shadow prices,
              complementary slackness verification
    """
    if result["status"] != "Optimal":
        print(f"  Skipping {result['group_id']} — no optimal solution.")
        return

    gid      = result["group_id"]
    filename = f"dual_{gid}.md"
    v        = verify_strong_duality(result)
    df       = result["shadow_df"]
    active   = df[df["shadow_price"].abs() > 1e-6].sort_values("shadow_price", ascending=False)

    lines = []

    # Header
    lines.append(f"# Duality Analysis — {gid.replace('_', ' ').title()}\n")
    lines.append(f"**Solver status:** {result['status']}  ")
    lines.append(f"**Z* (primal):** ${result['cost_usd']:.6f} USD  ")
    lines.append(f"**W* (dual):** ${v['w_star']:.6f} USD  ")
    lines.append(f"**Strong duality Z* = W*:** {'YES' if v['verified'] else 'NO'}\n")

    # Nutrient shadow prices
    nut_active = active[active["con_type"] != "group_cap"]
    lines.append("## Nutrient Shadow Prices (Binding Constraints)\n")
    lines.append(
        "Shadow price = cost increase in Z* from tightening that constraint by 1 unit.  \n"
        "Zero shadow price = non-binding constraint (complementary slackness).\n"
    )
    lines.append("| Nutrient | Constraint type | RHS | Shadow price (USD/unit) |")
    lines.append("|----------|----------------|----:|------------------------:|")
    for _, row in nut_active.iterrows():
        lines.append(
            f"| {row['nutrient']} "
            f"| {row['con_type']} "
            f"| {row['rhs']:.3f} "
            f"| ${row['shadow_price']:.6f} |"
        )
    lines.append("")

    # Group cap shadow prices
    grp_active = active[active["con_type"] == "group_cap"]
    lines.append("## Group Cap Shadow Prices (Binding Caps)\n")
    lines.append(
        "Shadow price = cost reduction in Z* from relaxing that cap by 1 gram.  \n"
        "Zero shadow price = cap is not binding for this group.\n"
    )
    lines.append("| Group | Cap (g) | Shadow price (USD/g) |")
    lines.append("|-------|--------:|--------------------:|")
    for _, row in grp_active.iterrows():
        lines.append(
            f"| {row['nutrient']} "
            f"| {row['rhs']:.1f} "
            f"| ${row['shadow_price']:.6f} |"
        )
    lines.append("")

    # Complementary slackness
    cs_df = verify_complementary_slackness(result)
    lines.append("## Complementary Slackness Verification\n")
    lines.append("| Nutrient / Group | Type | Slack | Shadow price | Binding | SP != 0 | CS holds |")
    lines.append("|------------------|------|------:|-------------:|:-------:|:-------:|:--------:|")
    for _, row in cs_df.iterrows():
        lines.append(
            f"| {row['nutrient']} "
            f"| {row['con_type']} "
            f"| {row['slack']:.6f} "
            f"| {row['shadow_price']:.6f} "
            f"| {'YES' if row['binding'] else 'no'} "
            f"| {'YES' if row['sp_nonzero'] else 'no'} "
            f"| {'OK' if row['cs_holds'] else 'VIOLATION'} |"
        )
    lines.append("")

    # Write and save
    os.makedirs(save_path, exist_ok=True)
    filepath = os.path.join(save_path, filename)
    with open(filepath, "w", encoding="utf-8") as f:
        f.write("\n".join(lines))

    print(f"  Saved: {filename}")

# %%
SAVE_PATH = "/Users/julianyoo/Downloads/Study/PWR/Term 1/Operations Research/Project/result/duality_01"
for result in dual_results:
    save_dual_md(result, save_path=SAVE_PATH)
# Out:
#   Saved: dual_children_4_8_MF.md
#   Saved: dual_males_9_13.md
#   Saved: dual_females_9_13.md
#   Saved: dual_males_14_18.md
#   Saved: dual_females_14_18.md

# %% [markdown]
# ## References
#
# ### LP Duality Theory
#
# Hillier, F. S., & Lieberman, G. J. (2015).
# *Introduction to operations research* (10th ed.). McGraw-Hill Education.
#
# Vanderbei, R. J. (2020).
# *Linear programming: Foundations and extensions* (5th ed.). Springer.
# https://doi.org/10.1007/978-3-030-39415-8
#
# ### LP Solver
#
# Huangfu, Q., & Hall, J. A. J. (2018).
# Parallelizing the dual revised simplex method.
# *Mathematical Programming Computation*, 10(1), 119–142.
# https://doi.org/10.1007/s12532-017-0130-5
#
# Virtanen, P., Gommers, R., Oliphant, T. E., Haberland, M., Reddy, T.,
# Cournapeau, D., … van der Walt, S. J. (2020).
# SciPy 1.0: Fundamental algorithms for scientific computing in Python.
# *Nature Methods*, 17, 261–272.
# https://doi.org/10.1038/s41592-019-0686-2
#
# ### Nutritional Data
#
# U.S. Department of Agriculture, Agricultural Research Service. (2019).
# *FoodData Central* (SR Legacy Foods / Foundation Foods).
# Retrieved from https://fdc.nal.usda.gov
#
# ### Food Price Data
#
# U.S. Bureau of Labor Statistics. (2024).
# *Average retail food prices — CPI average price series*.
# Retrieved from https://data.bls.gov
#
# ### Dietary Reference Intakes
#
# National Academies of Sciences, Engineering, and Medicine. (2019).
# *Dietary reference intakes for sodium and potassium* (revised).
# National Academies Press.
# https://doi.org/10.17226/25353
#
# U.S. Department of Agriculture & U.S. Department of Health and Human Services. (2020).
# *Dietary guidelines for Americans 2020–2025* (9th ed.).
# Retrieved from https://www.dietaryguidelines.gov
#
# ### School Nutrition Policy
#
# U.S. Department of Agriculture, Food and Nutrition Service. (2024).
# Child nutrition programs: Meal patterns consistent with the 2020–2025
# dietary guidelines for Americans. *Federal Register*, 89(81).
# Retrieved from https://www.federalregister.gov/documents/2024/04/25/2024-08098
